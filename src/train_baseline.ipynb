# %% [markdown]
# # Baseline YOLO11n trên VisDrone

# %%
pip install -q ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="VisDrone.yaml",
    epochs=100,
    patience=20,
    imgsz=640,
    batch=8,
    device=0,
    workers=2,
    seed=42
)
